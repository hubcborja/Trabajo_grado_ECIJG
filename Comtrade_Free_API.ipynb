# %% [markdown]
# <a href="https://colab.research.google.com/github/hubcborja/Trabajo_grado_ECIJG/blob/main/Comtrade_Free_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Codigo de API Comtrade
#
# Recuperado de https://github.com/uncomtrade/comtradeapicall/blob/main/tests/example%20calling%20functions%20-%20notebook.ipynb

# %% [markdown]
# ## Librerías y conexión

# %%
import sys
# !{sys.executable} -m pip install --upgrade comtradeapicall
# Out:
# Collecting comtradeapicall
#   Downloading comtradeapicall-1.3.0-py3-none-any.whl.metadata (21 kB)
# Downloading comtradeapicall-1.3.0-py3-none-any.whl (20 kB)
# Installing collected packages: comtradeapicall
# Successfully installed comtradeapicall-1.3.0

# %%
import pandas as pd
import numpy as np
import requests
import comtradeapicall
import time
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import os
from google.colab import drive

pd.set_option('display.max_columns', None)
pd.options.display.float_format = '{:.2f}'.format

# %%
import importlib.metadata
version = importlib.metadata.version("comtradeapicall")
print("comtradeapicall version:", version)
# Out:
# comtradeapicall version: 1.3.0

# %%
PrimaryKey='cde7e1ab17694a84a7554b02b5e8f489'
SecondaryKey='d46468208db74e9c8a3ec81fb5d876b2'

# %%
mydf = comtradeapicall.getFinalDataAvailability(subscription_key=PrimaryKey, typeCode='C', freqCode='A', clCode='HS',
                                                period='2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024,2025', reporterCode='170')
mydf
# Out:
#           datasetCode typeCode freqCode  period  reporterCode reporterISO  \
# 0   20170200601072100        C        A    2006           170         COL
# 1   20170200701082100        C        A    2007           170         COL
# 2   20170200801082100        C        A    2008           170         COL
# 3   20170200901082100        C        A    2009           170         COL
# 4   20170201001082100        C        A    2010           170         COL
# 5   20170201101082100        C        A    2011           170         COL
# 6   20170201201092100        C        A    2012           170         COL
# 7   20170201301092100        C        A    2013           170         COL
# 8   20170201401092100        C        A    2014           170         COL
# 9   20170201501092100        C        A    2015           170         COL
# 10  20170201601092100        C        A    2016           170         COL
# 11  20170201701182100        C        A    2017           170         COL
# 12  20170201801182100        C        A    2018           170         COL
# 13  20170201901182100        C        A    2019           170         COL
# 14  20170202001182100        C        A    2020           170         COL
# 15  20170202101182100        C        A    2021           170         COL
# 16  20170202201202100        C        A    2022           170         COL
# 17  20170202301202100        C        A    2023           170         COL
# 18  20170202401202100        C        A    2024           170         COL
#
#    reporterDesc classificationCode classificationSearchCode  \
# 0      Colombia                 H2                       HS
# 1      Colombia                 H3                       HS
# 2      Colombia                 H3                       HS
# 3      Colombia                 H3                       HS
# 4      Colombia                 H3                       HS
# 5      Colombia                 H3                       HS
# 6      Colombia                 H4                       HS
# 7      Colombia                 H4                       HS
# 8      Colombia                 H4                       HS
# 9      Colombia                 H4                       HS
# 10     Colombia                 H4                       HS
# 11     Colombia                 H5                       HS
# 12     Colombia                 H5                       HS
# 13     Colombia                 H5                       HS
# 14     Colombia                 H5                       HS
# 15     Colombia                 H5                       HS
# 16     Colombia                 H6                       HS
# 17     Colombia                 H6                       HS
# 18     Colombia                 H6                       HS
#
#     isOriginalClassification  isExtendedFlowCode  isExtendedPartnerCode  \
# 0                       True                True                   True
# 1                       True               False                   True
# 2                       True               False                   True
# 3                       True                True                   True
# 4                       True                True                   True
# 5                       True                True                   True
# 6                       True                True                   True
# 7                       True                True                   True
# 8                       True                True                   True
# 9                       True               False                   True
# 10                      True               False                   True
# 11                      True               False                   True
# 12                      True               False                   True
# 13                      True               False                   True
# 14                      True               False                   True
# 15                      True               False                   True
# 16                      True               False                   True
# 17                      True               False                   True
# 18                      True               False                   True
#
#     isExtendedPartner2Code  isExtendedCmdCode  isExtendedCustomsCode  \
# 0                    False               True                  False
# 1                    False               True                  False
# 2                    False               True                  False
# 3                    False               True                  False
# 4                    False               True                  False
# 5                    False               True                  False
# 6                    False               True                  False
# 7                    False               True                  False
# 8                    False               True                  False
# 9                    False               True                  False
# 10                   False               True                  False
# 11                    True               True                  False
# 12                    True               True                  False
# 13                    True               True                   True
# 14                    True               True                  False
# 15                    True               True                  False
# 16                    True               True                   True
# 17                    True               True                   True
# 18                    True               True                  False
#
#     isExtendedMotCode  totalRecords  datasetChecksum  \
# 0               False        144440       1467177480
# 1               False        145127       1275774234
# 2               False        144778       1521521383
# 3               False        147595       -583338098
# 4               False        149434      -1848505451
# 5               False        155867        377627254
# 6               False        156042        968658935
# 7               False        158505       -347970151
# 8               False        160368       1626408517
# 9               False        157146        983557154
# 10              False        158225      -1885371501
# 11               True       1349644      -1377630067
# 12               True       1367116      -1176784435
# 13               True       2884876        192638454
# 14               True       1419256        683623520
# 15               True       1484983        824612050
# 16               True       3090896       1171875941
# 17               True       3072312       -580089957
# 18               True       1550473        486048189
#
#                   firstReleased                 lastReleased
# 0        2007-03-19T08:11:57.28  2011-04-16T13:09:38.7333333
# 1   2008-05-02T16:57:17.7166667  2011-04-16T13:54:40.7066667
# 2   2009-04-09T11:26:40.2833333       2011-04-16T14:41:57.73
# 3   2010-03-02T12:31:00.6966667  2011-04-16T15:15:26.3166667
# 4   2011-03-03T14:32:08.0466667  2011-03-03T14:32:08.0466667
# 5   2012-03-21T18:25:49.9666667  2012-03-21T18:25:49.9666667
# 6         2013-09-07T14:23:33.2        2013-09-07T14:23:33.2
# 7         2014-04-04T18:31:41.8        2014-04-04T18:31:41.8
# 8        2015-07-23T14:29:48.01       2015-07-23T14:29:48.01
# 9        2016-09-01T19:10:30.06       2016-09-01T19:10:30.06
# 10        2017-05-05T19:09:35.3        2017-05-05T19:09:35.3
# 11       2018-07-09T13:01:27.39       2018-07-09T13:01:27.39
# 12  2019-04-22T08:03:27.4266667  2019-04-22T08:03:27.4266667
# 13       2020-06-29T16:09:46.98  2024-07-24T11:29:10.0833333
# 14  2021-08-04T01:25:08.1066667       2026-03-26T02:44:54.24
# 15  2022-06-02T20:26:52.2666667  2026-03-27T06:13:18.1433333
# 16  2023-10-12T00:45:16.5933333       2026-02-16T08:07:05.61
# 17  2024-06-11T18:43:13.9533333       2026-02-10T08:04:35.82
# 18  2025-10-01T16:40:42.3733333  2026-03-27T22:03:53.2533333

# %% [markdown]
# ## Obtención datos para Colombia 2021 a 2024

# %%
imp21 = comtradeapicall.getFinalData(subscription_key=PrimaryKey, typeCode='C', freqCode='A', clCode='HS', period='2021',
                                    reporterCode='170', cmdCode=None, flowCode='M', partnerCode=None,partner2Code=None,
                                    customsCode=None, motCode=None, maxRecords=100000, format_output='JSON',
                                    aggregateBy=None, breakdownMode='classic', countOnly=None, includeDesc=True)
imp22 = comtradeapicall.getFinalData(subscription_key=PrimaryKey, typeCode='C', freqCode='A', clCode='HS', period='2022',
                                    reporterCode='170', cmdCode=None, flowCode='M', partnerCode=None,partner2Code=None,
                                    customsCode=None, motCode=None, maxRecords=100000, format_output='JSON',
                                    aggregateBy=None, breakdownMode='classic', countOnly=None, includeDesc=True)
imp23 = comtradeapicall.getFinalData(subscription_key=PrimaryKey, typeCode='C', freqCode='A', clCode='HS', period='2023',
                                    reporterCode='170', cmdCode=None, flowCode='M', partnerCode=None,partner2Code=None,
                                    customsCode=None, motCode=None, maxRecords=100000, format_output='JSON',
                                    aggregateBy=None, breakdownMode='classic', countOnly=None, includeDesc=True)
imp24 = comtradeapicall.getFinalData(subscription_key=PrimaryKey, typeCode='C', freqCode='A', clCode='HS', period='2024',
                                    reporterCode='170', cmdCode=None, flowCode='M', partnerCode=None,partner2Code=None,
                                    customsCode=None, motCode=None, maxRecords=100000, format_output='JSON',
                                    aggregateBy=None, breakdownMode='classic', countOnly=None, includeDesc=True)

exp21 = comtradeapicall.getFinalData(subscription_key=PrimaryKey, typeCode='C', freqCode='A', clCode='HS', period='2021',
                                    reporterCode='170', cmdCode=None, flowCode='X', partnerCode=None,partner2Code=None,
                                    customsCode=None, motCode=None, maxRecords=100000, format_output='JSON',
                                    aggregateBy=None, breakdownMode='classic', countOnly=None, includeDesc=True)
exp22 = comtradeapicall.getFinalData(subscription_key=PrimaryKey, typeCode='C', freqCode='A', clCode='HS', period='2022',
                                    reporterCode='170', cmdCode=None, flowCode='X', partnerCode=None,partner2Code=None,
                                    customsCode=None, motCode=None, maxRecords=100000, format_output='JSON',
                                    aggregateBy=None, breakdownMode='classic', countOnly=None, includeDesc=True)
exp23 = comtradeapicall.getFinalData(subscription_key=PrimaryKey, typeCode='C', freqCode='A', clCode='HS', period='2023',
                                    reporterCode='170', cmdCode=None, flowCode='X', partnerCode=None,partner2Code=None,
                                    customsCode=None, motCode=None, maxRecords=100000, format_output='JSON',
                                    aggregateBy=None, breakdownMode='classic', countOnly=None, includeDesc=True)
exp24 = comtradeapicall.getFinalData(subscription_key=PrimaryKey, typeCode='C', freqCode='A', clCode='HS', period='2024',
                                    reporterCode='170', cmdCode=None, flowCode='X', partnerCode=None,partner2Code=None,
                                    customsCode=None, motCode=None, maxRecords=100000, format_output='JSON',
                                    aggregateBy=None, breakdownMode='classic', countOnly=None, includeDesc=True)

# %%
#Conteo para las importaciones
print(imp21['partnerCode'].size)
print(imp22['partnerCode'].size)
print(imp23['partnerCode'].size)
print(imp24['partnerCode'].size)
# Conteo para las exportaciones
print(exp21['partnerCode'].size)
print(exp21['partnerCode'].size)
print(exp21['partnerCode'].size)
print(exp21['partnerCode'].size)
# Out:
# 95155
# 99119
# 97152
# 97103
# 60447
# 60447
# 60447
# 60447

# %%
imports21_24=pd.concat([imp21, imp22, imp23, imp24])
exports21_24=pd.concat([exp21, exp22, exp23, exp24])

# %%
exports21_24
# Out:
#       typeCode freqCode  refPeriodId  refYear  refMonth period  reporterCode  \
# 0            C        A     20210101     2021        52   2021           170
# 1            C        A     20210101     2021        52   2021           170
# 2            C        A     20210101     2021        52   2021           170
# 3            C        A     20210101     2021        52   2021           170
# 4            C        A     20210101     2021        52   2021           170
# ...        ...      ...          ...      ...       ...    ...           ...
# 65878        C        A     20240101     2024        52   2024           170
# 65879        C        A     20240101     2024        52   2024           170
# 65880        C        A     20240101     2024        52   2024           170
# 65881        C        A     20240101     2024        52   2024           170
# 65882        C        A     20240101     2024        52   2024           170
#
#       reporterISO reporterDesc flowCode flowDesc  partnerCode partnerISO  \
# 0             COL     Colombia        X   Export            0        W00
# 1             COL     Colombia        X   Export           32        ARG
# 2             COL     Colombia        X   Export           40        AUT
# 3             COL     Colombia        X   Export           56        BEL
# 4             COL     Colombia        X   Export           68        BOL
# ...           ...          ...      ...      ...          ...        ...
# 65878         COL     Colombia        X   Export          860        UZB
# 65879         COL     Colombia        X   Export          862        VEN
# 65880         COL     Colombia        X   Export          887        YEM
# 65881         COL     Colombia        X   Export          894        ZMB
# 65882         COL     Colombia        X   Export          899        _X
#
#                             partnerDesc  partner2Code partner2ISO  \
# 0                                 World             0         W00
# 1                             Argentina             0         W00
# 2                               Austria             0         W00
# 3                               Belgium             0         W00
# 4      Bolivia (Plurinational State of)             0         W00
# ...                                 ...           ...         ...
# 65878                        Uzbekistan             0         W00
# 65879                         Venezuela             0         W00
# 65880                             Yemen             0         W00
# 65881                            Zambia             0         W00
# 65882                        Areas, nes             0         W00
#
#       partner2Desc classificationCode classificationSearchCode  \
# 0            World                 H5                       HS
# 1            World                 H5                       HS
# 2            World                 H5                       HS
# 3            World                 H5                       HS
# 4            World                 H5                       HS
# ...            ...                ...                      ...
# 65878        World                 H6                       HS
# 65879        World                 H6                       HS
# 65880        World                 H6                       HS
# 65881        World                 H6                       HS
# 65882        World                 H6                       HS
#
#        isOriginalClassification cmdCode          cmdDesc  aggrLevel  isLeaf  \
# 0                          True      01    Animals; live          2   False
# 1                          True      01    Animals; live          2   False
# 2                          True      01    Animals; live          2   False
# 3                          True      01    Animals; live          2   False
# 4                          True      01    Animals; live          2   False
# ...                         ...     ...              ...        ...     ...
# 65878                      True   TOTAL  All Commodities          0   False
# 65879                      True   TOTAL  All Commodities          0   False
# 65880                      True   TOTAL  All Commodities          0   False
# 65881                      True   TOTAL  All Commodities          0   False
# 65882                      True   TOTAL  All Commodities          0   False
#
#       customsCode customsDesc mosCode  motCode    motDesc  qtyUnitCode  \
# 0             C00   TOTAL CPC       0        0  TOTAL MOT           -1
# 1             C00   TOTAL CPC       0        0  TOTAL MOT           -1
# 2             C00   TOTAL CPC       0        0  TOTAL MOT           -1
# 3             C00   TOTAL CPC       0        0  TOTAL MOT           -1
# 4             C00   TOTAL CPC       0        0  TOTAL MOT           -1
# ...           ...         ...     ...      ...        ...          ...
# 65878         C00   TOTAL CPC       0        0  TOTAL MOT           -1
# 65879         C00   TOTAL CPC       0        0  TOTAL MOT           -1
# 65880         C00   TOTAL CPC       0        0  TOTAL MOT           -1
# 65881         C00   TOTAL CPC       0        0  TOTAL MOT           -1
# 65882         C00   TOTAL CPC       0        0  TOTAL MOT           -1
#
#       qtyUnitAbbr  qty  isQtyEstimated  altQtyUnitCode altQtyUnitAbbr  altQty  \
# 0             N/A 0.00           False              -1            N/A    0.00
# 1             N/A 0.00           False              -1            N/A    0.00
# 2             N/A 0.00           False              -1            N/A    0.00
# 3             N/A 0.00           False              -1            N/A    0.00
# 4             N/A 0.00           False              -1            N/A    0.00
# ...           ...  ...             ...             ...            ...     ...
# 65878         N/A 0.00           False              -1            N/A    0.00
# 65879         N/A 0.00           False              -1            N/A    0.00
# 65880         N/A 0.00           False              -1            N/A    0.00
# 65881         N/A 0.00           False              -1            N/A    0.00
# 65882         N/A 0.00           False              -1            N/A    0.00
#
#        isAltQtyEstimated  netWgt  isNetWgtEstimated  grossWgt  \
# 0                  False    0.00              False      0.00
# 1                  False    0.00              False      0.00
# 2                  False    0.00              False      0.00
# 3                  False    0.00              False      0.00
# 4                  False    0.00              False      0.00
# ...                  ...     ...                ...       ...
# 65878              False    0.00              False      0.00
# 65879              False    0.00               True      0.00
# 65880              False    0.00              False      0.00
# 65881              False    0.00              False      0.00
# 65882              False    0.00               True      0.00
#
#        isGrossWgtEstimated cifvalue      fobvalue  primaryValue  \
# 0                    False     None  160725206.52  160725206.52
# 1                    False     None       3015.00       3015.00
# 2                    False     None         50.00         50.00
# 3                    False     None        200.00        200.00
# 4                    False     None        830.00        830.00
# ...                    ...      ...           ...           ...
# 65878                False     None     645909.10     645909.10
# 65879                False     None 1003583583.61 1003583583.61
# 65880                False     None     292992.60     292992.60
# 65881                False     None     184012.60     184012.60
# 65882                False     None   18793159.87   18793159.87
#
#        legacyEstimationFlag  isReported  isAggregate
# 0                         0       False         True
# 1                         0       False         True
# 2                         0       False         True
# 3                         0       False         True
# 4                         0       False         True
# ...                     ...         ...          ...
# 65878                     0       False         True
# 65879                     4       False         True
# 65880                     0       False         True
# 65881                     0       False         True
# 65882                     4       False         True
#
# [251741 rows x 47 columns]

# %%
print(imports21_24['partnerCode'].unique().size)
print(exports21_24['partnerCode'].unique().size)
# Out:
# 219
# 199

# %%
print(imports21_24['partnerISO'].unique())
print(exports21_24['partnerISO'].unique())
# Out:
# ['W00' 'ARG' 'AUS' 'AUT' 'BEL' 'BOL' 'BRA' 'CAN' 'CHL' 'CRI' 'CZE' 'DNK'
#  'DOM' 'ECU' 'DEU' 'HUN' 'ITA' 'KOR' 'LTU' 'MEX' 'OMN' 'NLD' 'ABW' 'NGA'
#  'PAN' 'PER' 'PRT' 'QAT' 'ROU' 'RUS' 'VNM' 'ESP' 'CHE' 'THA' 'UKR' 'GBR'
#  'USA' 'URY' 'VEN' '_X ' 'PRY' 'SLB' 'MMR' 'CHN' 'GHA' 'GRL' 'GTM' 'ISL'
#  'IDN' 'CIV' 'JPN' 'MDV' 'MRT' 'MUS' 'S19' 'NZL' 'NOR' 'PAK' 'PHL' 'POL'
#  'SEN' 'SYC' 'IND' 'SUR' 'TTO' 'TUR' 'TZA' 'FRA' 'IRL' 'ISR' 'HND' 'KEN'
#  'ZAF' 'HKG' 'MAR' 'EGY' 'DZA' 'BGR' 'GEO' 'GRC' 'IRN' 'LBN' 'SGP' 'ARE'
#  'TUN' 'LKA' 'LBR' 'MDG' 'NPL' 'RWA' 'SYR' 'SLV' 'FIN' 'NIC' 'ALB' 'HRV'
#  'MYS' 'NAM' 'SDN' 'UZB' 'HTI' 'BEN' 'SWE' 'X2 ' 'SRB' 'SVK' 'SAU' 'SVN'
#  'JOR' 'EST' 'LVA' 'BRB' 'CUB' 'GUY' 'KHM' 'MOZ' 'BHR' 'BLR' 'CYP' 'JAM'
#  'MDA' 'PCN' 'BGD' 'BIH' 'GAB' 'KAZ' 'KWT' 'LUX' 'ARM' 'BLZ' 'PRK' 'MAC'
#  'MLT' 'SWZ' 'TKL' 'COM' 'LAO' 'CMR' 'PYF' 'CCK' 'SLE' 'ASM' 'ATG' 'AZE'
#  'BTN' 'COG' 'ERI' 'GMB' 'CUW' 'NER' 'KNA' 'AIA' 'MKD' 'CYM' 'FRO' 'IRQ'
#  'LBY' 'UGA' 'GRD' 'NRU' 'GIN' 'AND' 'COK' 'PLW' 'BRN' 'ETH' 'LSO' 'CPV'
#  'TJK' 'TKM' 'DMA' 'GUM' 'BWA' 'VGB' 'AFG' 'ATF' 'PSE' 'KGZ' 'VAT' 'MNG'
#  'NIU' 'SHN' 'SMR' 'STP' 'BHS' 'CAF' 'GIB' 'MWI' 'MLI' 'TON' 'TUV' 'WLF'
#  'MSR' 'NFK' 'FSM' 'BDI' 'AGO' 'FJI' 'BFA' 'PNG' 'MNP' 'TGO' 'WSM' 'NCL'
#  'ZWE' 'TCD' 'TLS' 'TCA' 'ZMB' 'BMU' 'CXR' 'IOT' 'MHL' 'VCT' 'BES' 'SOM'
#  'LCA' 'DJI' 'KIR']
# ['W00' 'ARG' 'AUT' 'BEL' 'BOL' 'BRA' 'CAN' 'CHL' 'CRI' 'CYP' 'CZE' 'DNK'
#  'DOM' 'ECU' 'SLV' 'EST' 'FRA' 'DEU' 'GTM' 'HND' 'HKG' 'HUN' 'IDN' 'IRQ'
#  'IRL' 'ISR' 'ITA' 'JPN' 'JOR' 'KOR' 'LBN' 'MYS' 'MLT' 'MEX' 'NAM' 'NLD'
#  'CUW' 'ABW' 'NOR' 'PAN' 'PRY' 'PER' 'PHL' 'PRT' 'ROU' 'RUS' 'SAU' 'IND'
#  'VNM' 'ZAF' 'ESP' 'SWE' 'CHE' 'THA' 'ARE' 'EGY' 'GBR' 'USA' 'URY' 'VEN'
#  'CHN' 'COG' 'GNQ' 'GAB' 'GEO' 'CIV' 'LBR' 'LBY' 'QAT' 'SLE' 'TUR' 'BGR'
#  'FIN' 'S19' 'OMN' 'PAK' 'POL' 'SGP' 'AUS' 'GUY' 'SUR' 'TTO' '_X ' 'SVK'
#  'X2 ' 'AFG' 'ATG' 'AZE' 'BHS' 'BHR' 'BIH' 'VGB' 'BLR' 'HRV' 'ETH' 'GHA'
#  'GRD' 'GUM' 'JAM' 'KAZ' 'KEN' 'PRK' 'KWT' 'KGZ' 'LVA' 'LTU' 'MDA' 'MNE'
#  'MAR' 'NZL' 'NIC' 'KNA' 'LCA' 'SVN' 'TJK' 'UKR' 'CUB' 'ALB' 'DZA' 'KHM'
#  'GRC' 'TUN' 'BRB' 'LKA' 'HTI' 'ISL' 'MAC' 'MNG' 'SYR' 'PYF' 'VCT' 'AGO'
#  'COD' 'NGA' 'UGA' 'DMA' 'BLZ' 'CMR' 'CPV' 'CAF' 'COM' 'BEN' 'FJI' 'PSE'
#  'GIN' 'MDG' 'MLI' 'MOZ' 'GNB' 'SEN' 'SDN' 'TON' 'MKD' 'TZA' 'BFA' 'YEM'
#  'CYM' 'BMU' 'BRN' 'BES' 'AIA' 'TCA' 'SRB' 'MRT' 'MMR' 'BGD' 'ARM' 'TGO'
#  'LAO' 'DJI' 'LUX' 'NCL' 'BDI' 'RWA' 'ZWE' 'MNP' 'TKM' 'MDV' 'ZMB' 'UZB'
#  'LSO' 'MUS' 'TCD' 'SYC' 'MSR' 'IOT' 'TLS' 'SOM' 'SMR' 'MWI' 'ASM' 'PNG'
#  'BWA' 'GMB' 'AND' 'NPL' 'NER' 'MHL' 'SWZ']

# %% [markdown]
# ### Determinación canasta báscia de productos de importación y exportación representativos

# %%
# Extraer canasta representativa 51% de las importaciones
imports21_24_sintotal=imports21_24[imports21_24['cmdCode']!='TOTAL']
imports21_24_sintotal=imports21_24_sintotal[~imports21_24_sintotal['partnerISO'].isin(['S19', 'X2 ', 'W00','_X '])]
imports21_24_partida=imports21_24_sintotal[imports21_24_sintotal['cmdCode'].str.len() == 4].copy()
imports21_24_partida=imports21_24_partida[~imports21_24_partida['cmdCode'].isin(['9999'])]
imports21_24_agr=imports21_24_partida.groupby(['cmdCode','cmdDesc'])['cifvalue'].sum().reset_index()
imports21_24_agr=imports21_24_agr.sort_values(by='cifvalue', ascending=False)
total_valorcif_imp=imports21_24_agr['cifvalue'].sum()
imports21_24_agr['part_cifvalue']=imports21_24_agr['cifvalue']/total_valorcif_imp
imports21_24_agr['part_acum']=imports21_24_agr['part_cifvalue'].cumsum()
cesta_imp=imports21_24_agr[imports21_24_agr['part_acum']<=0.51]
lista_cod_cesta_imp=cesta_imp['cmdCode'].tolist()
print(lista_cod_cesta_imp)

# Extraer canasta representativa 51% de las exportaciones
exports21_24_sintotal=exports21_24[exports21_24['cmdCode']!='TOTAL']
exports21_24_sintotal=exports21_24_sintotal[~exports21_24_sintotal['partnerISO'].isin(['S19', 'X2 ', 'W00','_X '])]
exports21_24_partida=exports21_24_sintotal[exports21_24_sintotal['cmdCode'].str.len() == 4].copy()
exports21_24_sintotal=exports21_24_sintotal[~exports21_24_sintotal['cmdCode'].isin(['9999'])]
exports21_24_agr=exports21_24_partida.groupby(['cmdCode','cmdDesc'])['fobvalue'].sum().reset_index()
exports21_24_agr=exports21_24_agr.sort_values(by='fobvalue', ascending=False)
total_valorcif_exp=exports21_24_agr['fobvalue'].sum()
exports21_24_agr['part_fobvalue']=exports21_24_agr['fobvalue']/total_valorcif_imp
exports21_24_agr['part_acum']=exports21_24_agr['part_fobvalue'].cumsum()
cesta_exp=exports21_24_agr[exports21_24_agr['part_acum']<=0.51]
lista_cod_cesta_exp=cesta_exp['cmdCode'].tolist()
print(lista_cod_cesta_exp)
# Out:
# ['2710', '8703', '3004', '8517', '1005', '3002', '8802', '8471', '2304', '8704', '3901', '1001', '8517', '4011', '8708', '9018', '8528', '3808', '7225', '7208', '2711', '2709', '3102', '2903', '3907', '3105', '8544', '2901', '1507', '8429', '0203', '8701', '3920', '2106', '9021', '7304', '8502', '7408', '3104', '8421', '8802', '8481', '8413']
# ['2709', '2701', '0901', '7108', '2710', '0603', '2704']

# %% [markdown]
# ### Determinación paises socios representativos en importación y exportación

# %%
# Extraer canasta representativa 75% de los paises que más colombia importa
imports21_24_sintotal=imports21_24[imports21_24['cmdCode']!='TOTAL']
imports21_24_sintotal=imports21_24_sintotal[~imports21_24_sintotal['partnerISO'].isin(['S19', 'X2 ', 'W00','_X '])]
imports21_24_partida=imports21_24_sintotal[imports21_24_sintotal['cmdCode'].str.len() == 4].copy()
imports21_24_partida=imports21_24_partida[~imports21_24_partida['cmdCode'].isin(['9999'])]
imports21_24_agr=imports21_24_partida.groupby(['partnerCode','partnerISO','partnerDesc'])['cifvalue'].sum().reset_index()
imports21_24_agr=imports21_24_agr.sort_values(by='cifvalue', ascending=False)
total_valorcif_imp=imports21_24_agr['cifvalue'].sum()
imports21_24_agr['part_cifvalue']=imports21_24_agr['cifvalue']/total_valorcif_imp
imports21_24_agr['part_acum']=imports21_24_agr['part_cifvalue'].cumsum()
paises_imp=imports21_24_agr[imports21_24_agr['part_acum']<=0.75]
lista_cod_paises_imp=paises_imp['partnerCode'].tolist()
lista_cod_paises_imp_iso=paises_imp['partnerISO'].tolist()
print(lista_cod_paises_imp_iso)

# Extraer canasta representativa 60% de los paises que más colombia exporta
exports21_24_sintotal=exports21_24[exports21_24['cmdCode']!='TOTAL']
exports21_24_sintotal=exports21_24_sintotal[~exports21_24_sintotal['partnerISO'].isin(['S19', 'X2 ', 'W00','_X '])]
exports21_24_partida=exports21_24_sintotal[exports21_24_sintotal['cmdCode'].str.len() == 4].copy()
exports21_24_sintotal=exports21_24_sintotal[~exports21_24_sintotal['cmdCode'].isin(['9999'])]
exports21_24_agr=exports21_24_partida.groupby(['partnerCode','partnerISO','partnerDesc'])['fobvalue'].sum().reset_index()
exports21_24_agr=exports21_24_agr.sort_values(by='fobvalue', ascending=False)
total_valorcif_exp=exports21_24_agr['fobvalue'].sum()
exports21_24_agr['part_fobvalue']=exports21_24_agr['fobvalue']/total_valorcif_imp
exports21_24_agr['part_acum']=exports21_24_agr['part_fobvalue'].cumsum()
paises_exp=exports21_24_agr[exports21_24_agr['part_acum']<=0.75]
lista_cod_paises_exp=paises_exp['partnerCode'].tolist()
lista_cod_paises_exp_iso=paises_exp['partnerISO'].tolist()
print(lista_cod_paises_exp_iso)
# Out:
# ['USA', 'CHN', 'BRA', 'MEX', 'DEU', 'FRA', 'JPN', 'IND', 'ARG']
# ['USA', 'PAN', 'CHN', 'IND', 'BRA', 'ECU', 'NLD', 'MEX', 'TUR', 'CHL', 'PER', 'ESP', 'ITA', 'KOR', 'CAN', 'DEU', 'VEN', 'DOM', 'BEL', 'JPN', 'ISR', 'GBR', 'POL', 'GTM', 'HKG', 'ARG', 'CRI', 'ARE', 'CIV', 'FRA', 'BHS', 'BES', 'EGY', 'SLV', 'AUS', 'JAM', 'MYS', 'CHE', 'HND', 'BOL', 'SGP', 'RUS', 'IRL', 'SAU', 'FIN', 'MAR', 'NOR', 'BRN', 'IDN', 'ZAF', 'LCA', 'SWE', 'CUB', 'HTI', 'ABW', 'TTO', 'SVN', 'IRQ', 'NIC', 'CUW', 'DNK']

# %% [markdown]
# ## Obtención de datos de exportación e importación para 10 años para paises socios representativos y canasta representativa

# %%
# Socios representativos (Se agrega Colombia y los que tienen acuerdos para evitar doble tributacion)
paises_convenio=[724, 152, 757, 124, 484, 410, 620, 699, 203, 251, 826, 784, 392, 380, 858, 528, 76, 442, 68, 218, 604]
socios_comerciales=list(set(lista_cod_paises_imp + lista_cod_paises_exp + paises_convenio + [170]))
# Años
chunks_anios = ['2014,2015,2016,2017,2018', '2019,2020,2021,2022,2023', '2024']
# Canasta representativa
lista_cestas=list(set(lista_cod_cesta_exp + lista_cod_cesta_imp))
cmd_cadena = ','.join(str(c) for c in lista_cestas)

# %%
print('Paises identificados como socios:', len(socios_comerciales))
print('Número de productos en la canasta:', len(lista_cestas))
# Out:
# Paises identificados como socios: 66
# Número de productos en la canasta: 46

# %%
exports_imports_socios=[]
# Bucle para la API para buscar la canasta en la importación y exportacion de los socios
for socio in socios_comerciales:
  for anio in chunks_anios:
    try:
        temp = comtradeapicall.getFinalData(subscription_key=PrimaryKey, typeCode='C', freqCode='A', clCode='HS', period=anio,
                                    reporterCode=str(socio), cmdCode=cmd_cadena, flowCode='M,X', partnerCode=None,partner2Code=None,
                                    customsCode=None, motCode=None, maxRecords=100000, format_output='JSON',
                                    aggregateBy=None, breakdownMode='classic', countOnly=None, includeDesc=True)
        exports_imports_socios.append(temp)
        print('Datos extraidos para:', temp['reporterISO'].unique(),'grupo años:', anio,'tamaño:', temp['reporterCode'].size)
        time.sleep(4)
    except Exception as e:
        print(f"Error en {str(socio)} para {anio}")
    continue
# Out:
# Datos extraidos para: ['CIV'] grupo años: 2014,2015,2016,2017,2018 tamaño: 12076
# Datos extraidos para: ['CIV'] grupo años: 2019,2020,2021,2022,2023 tamaño: 12593
# Datos extraidos para: ['CIV'] grupo años: 2024 tamaño: 2481
# Datos extraidos para: ['RUS'] grupo años: 2014,2015,2016,2017,2018 tamaño: 26773
# Datos extraidos para: ['RUS'] grupo años: 2019,2020,2021,2022,2023 tamaño: 16853
# Error en 643 para 2024
# Datos extraidos para: ['JAM'] grupo años: 2014,2015,2016,2017,2018 tamaño: 6988
# Datos extraidos para: ['JAM'] grupo años: 2019,2020,2021,2022,2023 tamaño: 7790
# Error en 388 para 2024
# Datos extraidos para: ['JPN'] grupo años: 2014,2015,2016,2017,2018 tamaño: 28069
# Datos extraidos para: ['JPN'] grupo años: 2019,2020,2021,2022,2023 tamaño: 27624
# Datos extraidos para: ['JPN'] grupo años: 2024 tamaño: 5583
# Datos extraidos para: ['TTO'] grupo años: 2014,2015,2016,2017,2018 tamaño: 9660
# Datos extraidos para: ['TTO'] grupo años: 2019,2020,2021,2022,2023 tamaño: 9526
# Datos extraidos para: ['TTO'] grupo años: 2024 tamaño: 1978
# Datos extraidos para: ['NLD'] grupo años: 2014,2015,2016,2017,2018 tamaño: 50500
# Datos extraidos para: ['NLD'] grupo años: 2019,2020,2021,2022,2023 tamaño: 49698
# Datos extraidos para: ['NLD'] grupo años: 2024 tamaño: 9905
# Datos extraidos para: ['ARE'] grupo años: 2014,2015,2016,2017,2018 tamaño: 29854
# Datos extraidos para: ['ARE'] grupo años: 2019,2020,2021,2022,2023 tamaño: 36941
# Error en 784 para 2024
# Datos extraidos para: ['CUW'] grupo años: 2014,2015,2016,2017,2018 tamaño: 1673
# Datos extraidos para: ['CUW'] grupo años: 2019,2020,2021,2022,2023 tamaño: 1611
# Error en 531 para 2024
# Datos extraidos para: ['DEU'] grupo años: 2014,2015,2016,2017,2018 tamaño: 45568
# Datos extraidos para: ['DEU'] grupo años: 2019,2020,2021,2022,2023 tamaño: 46379
# Datos extraidos para: ['DEU'] grupo años: 2024 tamaño: 9510
# Datos extraidos para: ['ABW'] grupo años: 2014,2015,2016,2017,2018 tamaño: 2039
# Datos extraidos para: ['ABW'] grupo años: 2019,2020,2021,2022,2023 tamaño: 1983
# Error en 533 para 2024
# Datos extraidos para: ['LCA'] grupo años: 2014,2015,2016,2017,2018 tamaño: 4689
# Datos extraidos para: ['LCA'] grupo años: 2019,2020,2021,2022,2023 tamaño: 2013
# Error en 662 para 2024
# Error en 535 para 2014,2015,2016,2017,2018
# Error en 535 para 2019,2020,2021,2022,2023
# Error en 535 para 2024
# Datos extraidos para: ['CHL'] grupo años: 2014,2015,2016,2017,2018 tamaño: 15194
# Datos extraidos para: ['CHL'] grupo años: 2019,2020,2021,2022,2023 tamaño: 15554
# Datos extraidos para: ['CHL'] grupo años: 2024 tamaño: 3113
# Datos extraidos para: ['TUR'] grupo años: 2014,2015,2016,2017,2018 tamaño: 32921
# Datos extraidos para: ['TUR'] grupo años: 2019,2020,2021,2022,2023 tamaño: 38314
# Datos extraidos para: ['TUR'] grupo años: 2024 tamaño: 8124
# Datos extraidos para: ['KOR'] grupo años: 2014,2015,2016,2017,2018 tamaño: 34781
# Datos extraidos para: ['KOR'] grupo años: 2019,2020,2021,2022,2023 tamaño: 35353
# Datos extraidos para: ['KOR'] grupo años: 2024 tamaño: 7138
# Datos extraidos para: ['CHN'] grupo años: 2014,2015,2016,2017,2018 tamaño: 42920
# Datos extraidos para: ['CHN'] grupo años: 2019,2020,2021,2022,2023 tamaño: 45114
# Datos extraidos para: ['CHN'] grupo años: 2024 tamaño: 9143
# Datos extraidos para: ['ARG'] grupo años: 2014,2015,2016,2017,2018 tamaño: 14442
# Datos extraidos para: ['ARG'] grupo años: 2019,2020,2021,2022,2023 tamaño: 10583
# Datos extraidos para: ['ARG'] grupo años: 2024 tamaño: 1960
# Datos extraidos para: ['AUS'] grupo años: 2014,2015,2016,2017,2018 tamaño: 25801
# Datos extraidos para: ['AUS'] grupo años: 2019,2020,2021,2022,2023 tamaño: 26582
# Datos extraidos para: ['AUS'] grupo años: 2024 tamaño: 5361
# Datos extraidos para: ['SAU'] grupo años: 2014,2015,2016,2017,2018 tamaño: 13946
# Datos extraidos para: ['SAU'] grupo años: 2019,2020,2021,2022,2023 tamaño: 17768
# Datos extraidos para: ['SAU'] grupo años: 2024 tamaño: 3730
# Datos extraidos para: ['COL'] grupo años: 2014,2015,2016,2017,2018 tamaño: 15289
# Datos extraidos para: ['COL'] grupo años: 2019,2020,2021,2022,2023 tamaño: 15602
# Datos extraidos para: ['COL'] grupo años: 2024 tamaño: 3168
# Datos extraidos para: ['BHS'] grupo años: 2014,2015,2016,2017,2018 tamaño: 3757
# Datos extraidos para: ['BHS'] grupo años: 2019,2020,2021,2022,2023 tamaño: 3920
# Datos extraidos para: ['BHS'] grupo años: 2024 tamaño: 810
# Datos extraidos para: ['NIC'] grupo años: 2014,2015,2016,2017,2018 tamaño: 8042
# Datos extraidos para: ['NIC'] grupo años: 2019,2020,2021,2022,2023 tamaño: 7915
# Datos extraidos para: ['NIC'] grupo años: 2024 tamaño: 1576
# Datos extraidos para: ['EGY'] grupo años: 2014,2015,2016,2017,2018 tamaño: 14756
# Datos extraidos para: ['EGY'] grupo años: 2019,2020,2021,2022,2023 tamaño: 17654
# Datos extraidos para: ['EGY'] grupo años: 2024 tamaño: 3644
# Datos extraidos para: ['BEL'] grupo años: 2014,2015,2016,2017,2018 tamaño: 39992
# Datos extraidos para: ['BEL'] grupo años: 2019,2020,2021,2022,2023 tamaño: 41576
# Datos extraidos para: ['BEL'] grupo años: 2024 tamaño: 8441
# Datos extraidos para: ['GBR'] grupo años: 2014,2015,2016,2017,2018 tamaño: 40940
# Datos extraidos para: ['GBR'] grupo años: 2019,2020,2021,2022,2023 tamaño: 42130
# Datos extraidos para: ['GBR'] grupo años: 2024 tamaño: 8351
# Datos extraidos para: ['IND'] grupo años: 2014,2015,2016,2017,2018 tamaño: 35653
# Datos extraidos para: ['IND'] grupo años: 2019,2020,2021,2022,2023 tamaño: 38160
# Datos extraidos para: ['IND'] grupo años: 2024 tamaño: 7713
# Datos extraidos para: ['CRI'] grupo años: 2014,2015,2016,2017,2018 tamaño: 12977
# Datos extraidos para: ['CRI'] grupo años: 2019,2020,2021,2022,2023 tamaño: 13238
# Datos extraidos para: ['CRI'] grupo años: 2024 tamaño: 2728
# Datos extraidos para: ['LUX'] grupo años: 2014,2015,2016,2017,2018 tamaño: 13798
# Datos extraidos para: ['LUX'] grupo años: 2019,2020,2021,2022,2023 tamaño: 17742
# Datos extraidos para: ['LUX'] grupo años: 2024 tamaño: 3610
# Datos extraidos para: ['SGP'] grupo años: 2014,2015,2016,2017,2018 tamaño: 28137
# Datos extraidos para: ['SGP'] grupo años: 2019,2020,2021,2022,2023 tamaño: 29321
# Datos extraidos para: ['SGP'] grupo años: 2024 tamaño: 5932
# Datos extraidos para: ['GTM'] grupo años: 2014,2015,2016,2017,2018 tamaño: 10372
# Datos extraidos para: ['GTM'] grupo años: 2019,2020,2021,2022,2023 tamaño: 11489
# Datos extraidos para: ['GTM'] grupo años: 2024 tamaño: 2513
# Datos extraidos para: ['CUB'] grupo años: 2014,2015,2016,2017,2018 tamaño: 4018
# Datos extraidos para: ['CUB'] grupo años: 2019,2020,2021,2022,2023 tamaño: 4895
# Error en 192 para 2024
# Datos extraidos para: ['SVN'] grupo años: 2014,2015,2016,2017,2018 tamaño: 20786
# Datos extraidos para: ['SVN'] grupo años: 2019,2020,2021,2022,2023 tamaño: 22251
# Datos extraidos para: ['SVN'] grupo años: 2024 tamaño: 4532
# Datos extraidos para: ['NOR'] grupo años: 2014,2015,2016,2017,2018 tamaño: 21440
# Datos extraidos para: ['NOR'] grupo años: 2019,2020,2021,2022,2023 tamaño: 22546
# Datos extraidos para: ['NOR'] grupo años: 2024 tamaño: 4615
# Datos extraidos para: ['BOL'] grupo años: 2014,2015,2016,2017,2018 tamaño: 8587
# Datos extraidos para: ['BOL'] grupo años: 2019,2020,2021,2022,2023 tamaño: 8668
# Datos extraidos para: ['BOL'] grupo años: 2024 tamaño: 1692
# Datos extraidos para: ['ZAF'] grupo años: 2014,2015,2016,2017,2018 tamaño: 31362
# Datos extraidos para: ['ZAF'] grupo años: 2019,2020,2021,2022,2023 tamaño: 32005
# Datos extraidos para: ['ZAF'] grupo años: 2024 tamaño: 6462
# Datos extraidos para: ['USA'] grupo años: 2014,2015,2016,2017,2018 tamaño: 45217
# Datos extraidos para: ['USA'] grupo años: 2019,2020,2021,2022,2023 tamaño: 45744
# Datos extraidos para: ['USA'] grupo años: 2024 tamaño: 9121
# Datos extraidos para: ['MYS'] grupo años: 2014,2015,2016,2017,2018 tamaño: 22274
# Datos extraidos para: ['MYS'] grupo años: 2019,2020,2021,2022,2023 tamaño: 23869
# Datos extraidos para: ['MYS'] grupo años: 2024 tamaño: 5446
# Datos extraidos para: ['BRA'] grupo años: 2014,2015,2016,2017,2018 tamaño: 24592
# Datos extraidos para: ['BRA'] grupo años: 2019,2020,2021,2022,2023 tamaño: 28027
# Datos extraidos para: ['BRA'] grupo años: 2024 tamaño: 5642
# Datos extraidos para: ['HTI'] grupo años: 2014,2015,2016,2017,2018 tamaño: 2978
# Error en 332 para 2019,2020,2021,2022,2023
# Error en 332 para 2024
# Datos extraidos para: ['CZE'] grupo años: 2014,2015,2016,2017,2018 tamaño: 29242
# Datos extraidos para: ['CZE'] grupo años: 2019,2020,2021,2022,2023 tamaño: 31245
# Datos extraidos para: ['CZE'] grupo años: 2024 tamaño: 6332
# Datos extraidos para: ['PAN'] grupo años: 2014,2015,2016,2017,2018 tamaño: 11479
# Datos extraidos para: ['PAN'] grupo años: 2019,2020,2021,2022,2023 tamaño: 9080
# Datos extraidos para: ['PAN'] grupo años: 2024 tamaño: 1671
# Datos extraidos para: ['DNK'] grupo años: 2014,2015,2016,2017,2018 tamaño: 28419
# Datos extraidos para: ['DNK'] grupo años: 2019,2020,2021,2022,2023 tamaño: 30724
# Datos extraidos para: ['DNK'] grupo años: 2024 tamaño: 6350
# Datos extraidos para: ['ESP'] grupo años: 2014,2015,2016,2017,2018 tamaño: 39281
# Datos extraidos para: ['ESP'] grupo años: 2019,2020,2021,2022,2023 tamaño: 39870
# Datos extraidos para: ['ESP'] grupo años: 2024 tamaño: 8171
# Datos extraidos para: ['HND'] grupo años: 2014,2015,2016,2017,2018 tamaño: 8970
# Datos extraidos para: ['HND'] grupo años: 2019,2020,2021,2022,2023 tamaño: 7311
# Datos extraidos para: ['HND'] grupo años: 2024 tamaño: 1840
# Datos extraidos para: ['DOM'] grupo años: 2014,2015,2016,2017,2018 tamaño: 11669
# Datos extraidos para: ['DOM'] grupo años: 2019,2020,2021,2022,2023 tamaño: 11124
# Datos extraidos para: ['DOM'] grupo años: 2024 tamaño: 2087
# Datos extraidos para: ['HKG'] grupo años: 2014,2015,2016,2017,2018 tamaño: 18669
# Datos extraidos para: ['HKG'] grupo años: 2019,2020,2021,2022,2023 tamaño: 18663
# Datos extraidos para: ['HKG'] grupo años: 2024 tamaño: 3806
# Datos extraidos para: ['ECU'] grupo años: 2014,2015,2016,2017,2018 tamaño: 10848
# Datos extraidos para: ['ECU'] grupo años: 2019,2020,2021,2022,2023 tamaño: 11429
# Datos extraidos para: ['ECU'] grupo años: 2024 tamaño: 2374
# Datos extraidos para: ['URY'] grupo años: 2014,2015,2016,2017,2018 tamaño: 8861
# Datos extraidos para: ['URY'] grupo años: 2019,2020,2021,2022,2023 tamaño: 9211
# Datos extraidos para: ['URY'] grupo años: 2024 tamaño: 1880
# Datos extraidos para: ['PER'] grupo años: 2014,2015,2016,2017,2018 tamaño: 13484
# Datos extraidos para: ['PER'] grupo años: 2019,2020,2021,2022,2023 tamaño: 13912
# Datos extraidos para: ['PER'] grupo años: 2024 tamaño: 2871
# Error en 862 para 2014,2015,2016,2017,2018
# Error en 862 para 2019,2020,2021,2022,2023
# Error en 862 para 2024
# Datos extraidos para: ['SLV'] grupo años: 2014,2015,2016,2017,2018 tamaño: 8834
# Datos extraidos para: ['SLV'] grupo años: 2019,2020,2021,2022,2023 tamaño: 9604
# Datos extraidos para: ['SLV'] grupo años: 2024 tamaño: 2037
# Datos extraidos para: ['BRN'] grupo años: 2014,2015,2016,2017,2018 tamaño: 6318
# Datos extraidos para: ['BRN'] grupo años: 2019,2020,2021,2022,2023 tamaño: 7000
# Datos extraidos para: ['BRN'] grupo años: 2024 tamaño: 1112
# Datos extraidos para: ['MEX'] grupo años: 2014,2015,2016,2017,2018 tamaño: 13999
# Datos extraidos para: ['MEX'] grupo años: 2019,2020,2021,2022,2023 tamaño: 12390
# Datos extraidos para: ['MEX'] grupo años: 2024 tamaño: 2206
# Datos extraidos para: ['ISR'] grupo años: 2014,2015,2016,2017,2018 tamaño: 18329
# Datos extraidos para: ['ISR'] grupo años: 2019,2020,2021,2022,2023 tamaño: 18707
# Datos extraidos para: ['ISR'] grupo años: 2024 tamaño: 3668
# Datos extraidos para: ['POL'] grupo años: 2014,2015,2016,2017,2018 tamaño: 31833
# Datos extraidos para: ['POL'] grupo años: 2019,2020,2021,2022,2023 tamaño: 34510
# Datos extraidos para: ['POL'] grupo años: 2024 tamaño: 7102
# Datos extraidos para: ['MAR'] grupo años: 2014,2015,2016,2017,2018 tamaño: 13136
# Datos extraidos para: ['MAR'] grupo años: 2019,2020,2021,2022,2023 tamaño: 14375
# Datos extraidos para: ['MAR'] grupo años: 2024 tamaño: 3024
# Datos extraidos para: ['IDN'] grupo años: 2014,2015,2016,2017,2018 tamaño: 19634
# Datos extraidos para: ['IDN'] grupo años: 2019,2020,2021,2022,2023 tamaño: 21911
# Datos extraidos para: ['IDN'] grupo años: 2024 tamaño: 4682
# Datos extraidos para: ['PRT'] grupo años: 2014,2015,2016,2017,2018 tamaño: 22695
# Datos extraidos para: ['PRT'] grupo años: 2019,2020,2021,2022,2023 tamaño: 25476
# Datos extraidos para: ['PRT'] grupo años: 2024 tamaño: 5220
# Datos extraidos para: ['SWE'] grupo años: 2014,2015,2016,2017,2018 tamaño: 29386
# Datos extraidos para: ['SWE'] grupo años: 2019,2020,2021,2022,2023 tamaño: 30726
# Datos extraidos para: ['SWE'] grupo años: 2024 tamaño: 6072
# Datos extraidos para: ['IRQ'] grupo años: 2014,2015,2016,2017,2018 tamaño: 620
# Error en 368 para 2019,2020,2021,2022,2023
# Error en 368 para 2024
# Datos extraidos para: ['IRL'] grupo años: 2014,2015,2016,2017,2018 tamaño: 20810
# Datos extraidos para: ['IRL'] grupo años: 2019,2020,2021,2022,2023 tamaño: 25241
# Datos extraidos para: ['IRL'] grupo años: 2024 tamaño: 5532
# Datos extraidos para: ['CHE'] grupo años: 2014,2015,2016,2017,2018 tamaño: 32487
# Datos extraidos para: ['CHE'] grupo años: 2019,2020,2021,2022,2023 tamaño: 32889
# Datos extraidos para: ['CHE'] grupo años: 2024 tamaño: 6541
# Datos extraidos para: ['FIN'] grupo años: 2014,2015,2016,2017,2018 tamaño: 22464
# Datos extraidos para: ['FIN'] grupo años: 2019,2020,2021,2022,2023 tamaño: 24146
# Datos extraidos para: ['FIN'] grupo años: 2024 tamaño: 4805
# Datos extraidos para: ['ITA'] grupo años: 2014,2015,2016,2017,2018 tamaño: 39793
# Datos extraidos para: ['ITA'] grupo años: 2019,2020,2021,2022,2023 tamaño: 40200
# Datos extraidos para: ['ITA'] grupo años: 2024 tamaño: 8061
# Datos extraidos para: ['FRA'] grupo años: 2014,2015,2016,2017,2018 tamaño: 46399
# Datos extraidos para: ['FRA'] grupo años: 2019,2020,2021,2022,2023 tamaño: 48445
# Datos extraidos para: ['FRA'] grupo años: 2024 tamaño: 9815
# Datos extraidos para: ['CAN'] grupo años: 2014,2015,2016,2017,2018 tamaño: 35111
# Datos extraidos para: ['CAN'] grupo años: 2019,2020,2021,2022,2023 tamaño: 35147
# Datos extraidos para: ['CAN'] grupo años: 2024 tamaño: 7005

# %%
# Limpieza de la base para zonas sin identificar y otros productos
exports_imports_socios_red_commodities = pd.concat(exports_imports_socios, ignore_index=True)
exports_imports_socios_red_commodities=exports_imports_socios_red_commodities[exports_imports_socios_red_commodities['cmdCode']!='TOTAL']
exports_imports_socios_red_commodities=exports_imports_socios_red_commodities[~exports_imports_socios_red_commodities['partnerISO'].isin(['X1 ','XX ','X2 ', 'W00','_X '])]

print(exports_imports_socios_red_commodities['reporterCode'].size)
exports_imports_socios_red_commodities.head()
# Out:
# /tmp/ipykernel_31039/2900005240.py:2: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   exports_imports_socios_red_commodities = pd.concat(exports_imports_socios, ignore_index=True)
# 2927517
#   typeCode freqCode  refPeriodId  refYear  refMonth period  reporterCode  \
# 1        C        A     20140101     2014        52   2014           384
# 2        C        A     20140101     2014        52   2014           384
# 3        C        A     20140101     2014        52   2014           384
# 4        C        A     20140101     2014        52   2014           384
# 5        C        A     20140101     2014        52   2014           384
#
#   reporterISO   reporterDesc flowCode flowDesc  partnerCode partnerISO  \
# 1         CIV  Côte d'Ivoire        M   Import           36        AUS
# 2         CIV  Côte d'Ivoire        M   Import           40        AUT
# 3         CIV  Côte d'Ivoire        M   Import           56        BEL
# 4         CIV  Côte d'Ivoire        M   Import           76        BRA
# 5         CIV  Côte d'Ivoire        M   Import          208        DNK
#
#   partnerDesc  partner2Code partner2ISO partner2Desc classificationCode  \
# 1   Australia             0         W00        World                 H3
# 2     Austria             0         W00        World                 H3
# 3     Belgium             0         W00        World                 H3
# 4      Brazil             0         W00        World                 H3
# 5     Denmark             0         W00        World                 H3
#
#   classificationSearchCode  isOriginalClassification cmdCode  \
# 1                       HS                      True    0203
# 2                       HS                      True    0203
# 3                       HS                      True    0203
# 4                       HS                      True    0203
# 5                       HS                      True    0203
#
#                                    cmdDesc  aggrLevel  isLeaf customsCode  \
# 1  Meat of swine; fresh, chilled or frozen          4   False         C00
# 2  Meat of swine; fresh, chilled or frozen          4   False         C00
# 3  Meat of swine; fresh, chilled or frozen          4   False         C00
# 4  Meat of swine; fresh, chilled or frozen          4   False         C00
# 5  Meat of swine; fresh, chilled or frozen          4   False         C00
#
#   customsDesc mosCode  motCode    motDesc  qtyUnitCode qtyUnitAbbr       qty  \
# 1   TOTAL CPC       0        0  TOTAL MOT            8          kg     50.00
# 2   TOTAL CPC       0        0  TOTAL MOT            8          kg  19000.00
# 3   TOTAL CPC       0        0  TOTAL MOT            8          kg  30480.00
# 4   TOTAL CPC       0        0  TOTAL MOT            8          kg 195735.00
# 5   TOTAL CPC       0        0  TOTAL MOT            8          kg 311369.00
#
#    isQtyEstimated  altQtyUnitCode altQtyUnitAbbr    altQty  isAltQtyEstimated  \
# 1           False               8             kg     50.00              False
# 2           False               8             kg  19000.00              False
# 3           False               8             kg  30480.00              False
# 4           False               8             kg 195735.00              False
# 5           False               8             kg 311369.00              False
#
#      netWgt  isNetWgtEstimated  grossWgt  isGrossWgtEstimated  cifvalue  \
# 1     50.00              False      0.00                False    568.20
# 2  19000.00              False      0.00                False  15786.76
# 3  30480.00              False      0.00                False  23546.41
# 4 195735.00              False      0.00                False 163703.57
# 5 311369.00              False      0.00                False 250980.24
#
#    fobvalue  primaryValue  legacyEstimationFlag  isReported  isAggregate
# 1       NaN        568.20                     0       False         True
# 2       NaN      15786.76                     0       False         True
# 3       NaN      23546.41                     0       False         True
# 4       NaN     163703.57                     0       False         True
# 5       NaN     250980.24                     0       False         True

# %%
#Verificación de la canasta básica y de los socios
codigos_descargados = set(exports_imports_socios_red_commodities['cmdCode'].unique())
codigos_esperados = set(lista_cestas)
codigos_faltantes = codigos_esperados - codigos_descargados
print(codigos_faltantes)

socios_descargados = set(exports_imports_socios_red_commodities['reporterCode'].unique())
socios_esperados = set(socios_comerciales)
socios_faltantes = socios_esperados - socios_descargados
print(socios_faltantes)
# Out:
# set()
# {862, 535}

# %%
# Importacion diccionario desde Comtrade para verificar los ISO3 correctos
datos_json = requests.get("https://comtradeapi.un.org/files/v1/app/reference/Reporters.json").json()
df_paises = pd.DataFrame(datos_json['results'])

columnas_reporters = ['id', 'text', 'reporterCodeIsoAlpha3']
columnas_exist = [col for col in columnas_reporters if col in df_paises.columns]

df_diccionario_paises = df_paises[columnas_exist].copy()

df_diccionario_paises.rename(columns={'id': 'partnerCode',
                                      'text': 'country_name',
                                      'reporterCodeIsoAlpha3': 'iso3'}, inplace=True)

print(df_diccionario_paises.head())
# Out:
#    partnerCode country_name iso3
# 0            4  Afghanistan  AFG
# 1            8      Albania  ALB
# 2           12      Algeria  DZA
# 3           20      Andorra  AND
# 4           24       Angola  AGO

# %%
# merge para garantizar que el Reporter tenga su ISO3 correcto para reporter y partner
base_red = exports_imports_socios_red_commodities.merge(df_diccionario_paises[['partnerCode', 'iso3']],
                                                        left_on='reporterCode',
                                                        right_on='partnerCode',
                                                        how='left').rename(columns={'iso3': 'reporter_iso_limpio'}).drop('partnerCode_y', axis=1)

base_red = base_red.merge(df_diccionario_paises[['partnerCode', 'iso3']],
                          left_on='partnerCode_x',
                          right_on='partnerCode',
                          how='left').rename(columns={'iso3': 'partner_iso_limpio'})

# %%
drive.mount('/content/drive')
ruta_drive = '/content/drive/MyDrive/Tesis_CDT_Datos'
os.makedirs(ruta_drive, exist_ok=True)
nombre_archivo = 'base_completa_comtrade_anual_2014_2024.csv'
base_red.to_csv(os.path.join(ruta_drive, nombre_archivo), index=False)
# Out:
# Mounted at /content/drive

# %%
# Se agrupa por año, origen, destino y expo o impo y sumamos el valor
flujos_consolidados = base_red.groupby(['period', 'reporter_iso_limpio', 'partner_iso_limpio', 'flowCode'])['primaryValue'].sum().reset_index()

# Se filtra para los socios de interés (Preguntar acerca de este paso)
lista_iso_socios = df_diccionario_paises[df_diccionario_paises['partnerCode'].isin(socios_comerciales)]['iso3'].tolist()
flujos_consolidados = flujos_consolidados[(flujos_consolidados['reporter_iso_limpio'].isin(lista_iso_socios)) &(flujos_consolidados['partner_iso_limpio'].isin(lista_iso_socios))]
flujos_consolidados.head(1)
# Out:
#   period reporter_iso_limpio partner_iso_limpio flowCode  primaryValue
# 0   2014                 ABW                BRA        M    1529010.00

# %%
# Pivotar tabla
red_final = flujos_consolidados.pivot_table(index=['period', 'reporter_iso_limpio', 'partner_iso_limpio'],
                                            columns='flowCode',
                                            values='primaryValue',
                                            fill_value=0).reset_index()

# Peso para la red
red_final['peso_comercio_total'] = red_final['M'] + red_final['X']
red_final['balanza_comercial'] = red_final['X'] - red_final['M']

nombre_archivo = 'Comtrade_canasta_socios_significativos_2014_2024.csv'
red_final.to_csv(os.path.join(ruta_drive, nombre_archivo), index=False)

print(red_final.shape)
red_final.head()
# Out:
# (41021, 7)
# flowCode period reporter_iso_limpio partner_iso_limpio          M          X  \
# 0          2014                 ABW                BRA 1529010.00       0.00
# 1          2014                 ABW                CHE  261464.00       0.00
# 2          2014                 ABW                CHN 5699849.00       0.00
# 3          2014                 ABW                COL  851884.00  441832.00
# 4          2014                 ABW                CUW 3524704.00 1171690.00
#
# flowCode  peso_comercio_total  balanza_comercial
# 0                  1529010.00        -1529010.00
# 1                   261464.00         -261464.00
# 2                  5699849.00        -5699849.00
# 3                  1293716.00         -410052.00
# 4                  4696394.00        -2353014.00

# %%
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# %%
G = nx.from_pandas_edgelist(red_final,
                            source='reporter_iso_limpio',
                            target='partner_iso_limpio',
                            edge_attr='peso_comercio_total')

# %%
plt.figure(figsize=(10, 8))
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True, node_color='lightblue', node_size=200, font_size=10)
plt.title("Red completa de comercio socios y productos relevantes Colombia", size=15)
plt.show()

# %%
red_final.to_csv('20260328_red_socios_XM.csv', index=False)

# %% [markdown]
# # Red de Convenios para evitar la doble tributación

# %%
base_convenios=pd.read_csv('https://raw.githubusercontent.com/hubcborja/Trabajo_grado_ECIJG/refs/heads/main/bases_datos/convenios_tributarios.csv')
renombrar_columnas = {
    'Source': 'indice_fuente_total',                   # Que tanto beneficia al pais fuente
    'PE': 'indice_establecimiento_permanente',         # Que tanto se le cobran a los establecimientos permanentes
    'WHT Rates': 'indice_tasas_retencion',             # Que tanto tienen de topes las tasas de retención
    'Other': 'indice_otros_derechos',                  # Indice de los otros derechos del convenio
    'UN': 'indice_modelo_onu',                          # Que tanto se parece al modelo ONU (que favorece a los estado en desarrollo)
    '5(3)(a)C': 'duracion_ep_construccion_meses',      # Construction PE length
    '5(3)(a)S': 'actividades_supervision_ep',          # Supervisory activities in PE
    '5(3)(b)': 'duracion_ep_servicios_meses',          # Service PE length
    '5(4)(a)': 'instalaciones_entrega_excluidas_ep',   # Delivery facilities excluded
    '5(4)(b)': 'inventario_entrega_excluido_ep',       # Delivery stock excluded
    '5(5)(b)': 'agente_con_inventario_ep',             # Agent maintaining stock included
    '5(6)': 'corredor_seguros_ep',                     # Insurance broker included
    '5(7)': 'extension_agente_dependiente_ep',         # Dependent agent extension
    '7(1)(b&c)': 'fuerza_atraccion_limitada',          # Limited force of attraction
    '7(3)': 'sin_deduccion_pagos_matriz',              # No deduction payments to head office
    '8(2)': 'impuesto_transporte_maritimo',            # Shared taxing right shipping
    '10(2)(a)Q': 'tasa_retencion_dividendos_calificados', # Qualifying dividend WHT rate
    '10(2)(a)T': 'umbral_participacion_dividendos',    # Threshold for qualified dividends
    '10(2)(b)': 'tasa_retencion_dividendos_portafolio',# Portfolio dividend WHT rate
    '11(2)': 'tasa_retencion_intereses',               # Interest WHT rate
    '11(2)F': 'tasa_retencion_intereses_financieras',  # Financial inst. interest rate
    '12(2)': 'tasa_retencion_regalias',                # Royalties WHT rate
    '12(2)C': 'tasa_retencion_regalias_derechos_autor',# Copyright royalties rate
    '12(2)E': 'tasa_retencion_regalias_equipos',       # Equipment royalties rate
    '12(A)': 'tasa_retencion_servicios_tecnicos',      # Technical service fees rate
    '13(4)': 'ganancia_capital_inmobiliaria',          # Capital gains (land rich)
    '13(5)': 'ganancia_capital_otras_acciones',        # Capital gains (other shares)
    '14': 'servicios_personales_independientes',       # Independent personal services
    '16(2)': 'oficiales_alta_gerencia',                # Top-level managerial officials
    '21(3)': 'impuesto_fuente_otros_ingresos',         # Source taxation other income
    '25B(5)': 'arbitraje_obligatorio_vinculante',      # Mandatory binding arbitration
    '27': 'asistencia_cobro_impuestos',                # Assistance in tax collection
    '29': 'regla_general_anti_abuso'                   # General anti-abuse rule (GAAR)
}


base_convenios.rename(columns=renombrar_columnas, inplace=True)
base_convenios.head()
# Out:
#   Country A Country B      Type  Date of signature  Effective    Status  \
# 0   Albania    Israel  Original               2021    2022.00  In Force
# 1   Albania    Turkey  Original               1994    1997.00  In Force
# 2   Albania   Romania  Original               1994    1995.00  In Force
# 3   Albania     Italy  Original               1994    2000.00  In Force
# 4   Albania    Russia  Original               1995    1998.00  In Force
#
#    indice_fuente_total  WHTrates  indice_establecimiento_permanente  \
# 0                 0.30      0.31                               0.45
# 1                 0.19      0.38                               0.06
# 2                 0.47      0.47                               0.58
# 3                 0.19      0.25                               0.19
# 4                 0.23      0.38                               0.06
#
#    indice_otros_derechos  indice_modelo_onu  duracion_ep_construccion_meses  \
# 0                   0.13               0.26                            9.00
# 1                   0.13               0.06                           12.00
# 2                   0.38               0.44                            9.00
# 3                   0.13               0.12                           12.00
# 4                   0.25               0.12                           12.00
#
#   actividades_supervision_ep duracion_ep_servicios_meses  \
# 0                        YES                          12
# 1                         NO                          NO
# 2                        YES                           9
# 3                         NO                          NO
# 4                         NO                          NO
#
#   instalaciones_entrega_excluidas_ep inventario_entrega_excluido_ep  \
# 0                                YES                            YES
# 1                                YES                            YES
# 2                                YES                            YES
# 3                                YES                            YES
# 4                                YES                            YES
#
#   agente_con_inventario_ep corredor_seguros_ep  \
# 0                       NO                  NO
# 1                       NO                  NO
# 2                      YES                  NO
# 3                      YES                  NO
# 4                       NO                  NO
#
#   extension_agente_dependiente_ep fuerza_atraccion_limitada  \
# 0                             YES                        NO
# 1                              NO                        NO
# 2                             YES                       YES
# 3                              NO                        NO
# 4                              NO                        NO
#
#   sin_deduccion_pagos_matriz impuesto_transporte_maritimo  \
# 0                         NO                           NO
# 1                         NO                           NO
# 2                         NO                           NO
# 3                         NO                           NO
# 4                         NO                           NO
#
#   tasa_retencion_dividendos_calificados  umbral_participacion_dividendos  \
# 0                                     5                            25.00
# 1                                     5                            25.00
# 2                                    10                            25.00
# 3                                    10                              NaN
# 4                                    10                              NaN
#
#   tasa_retencion_dividendos_portafolio tasa_retencion_intereses  \
# 0                                   15                       10
# 1                                   15                       10
# 2                                   15                       10
# 3                                   10                        5
# 4                                   10                       10
#
#   tasa_retencion_intereses_financieras tasa_retencion_regalias  \
# 0                                   10                       5
# 1                                   10                      10
# 2                                   10                      15
# 3                                    5                       5
# 4                                   10                      10
#
#   tasa_retencion_regalias_derechos_autor tasa_retencion_regalias_equipos  \
# 0                                      5                               5
# 1                                     10                              10
# 2                                     15                              15
# 3                                      5                               5
# 4                                     10                              10
#
#   tasa_retencion_servicios_tecnicos ganancia_capital_inmobiliaria  \
# 0                                 0                           YES
# 1                                 0                            NO
# 2                                 0                            NO
# 3                                 0                            NO
# 4                                 0                            NO
#
#   ganancia_capital_otras_acciones servicios_personales_independientes  \
# 0                              NO                                  NO
# 1                              NO                                 YES
# 2                              NO                                 YES
# 3                              NO                                 YES
# 4                              NO                                 YES
#
#   oficiales_alta_gerencia impuesto_fuente_otros_ingresos  \
# 0                      NO                             NO
# 1                      NO                             NO
# 2                      NO                            YES
# 3                      NO                             NO
# 4                      NO                            YES
#
#   arbitraje_obligatorio_vinculante asistencia_cobro_impuestos  \
# 0                               NO                         NO
# 1                               NO                         NO
# 2                               NO                         NO
# 3                               NO                         NO
# 4                               NO                         NO
#
#   regla_general_anti_abuso
# 0                      PPT
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
